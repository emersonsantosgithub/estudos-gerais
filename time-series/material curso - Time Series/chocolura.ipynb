# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("chocolura.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mes     24 non-null     object
#  1   vendas  24 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 516.0+ bytes

# %%
print(f"Quantidade de linha e colunas", df.shape)
print(f"Quantidade de dados nulos", df.isna().sum().sum())
# Out:
# Quantidade de linha e colunas (24, 2)
# Quantidade de dados nulos 0

# %%
df['mes']= pd.to_datetime(df['mes'])

# %%
df['Aumento'] = df['vendas'].diff()
df['Aceleracao'] = df['Aumento'].diff()

# %%
def plotagem_graficos_tres():
    plt.figure(figsize=(12, 10))
    sns.set_style("darkgrid")

    # Primeiro gráfico
    ax1 = plt.subplot(3, 1, 1)
    sns.lineplot(data=df, x='mes', y='vendas', ax=ax1)
    ax1.set_title("Quantidade de vendas")

    # Segundo gráfico
    ax2 = plt.subplot(3, 1, 2)
    sns.lineplot(data=df, x='mes', y='Aumento', ax=ax2)
    ax2.set_title("Dados do aumento")

    # Terceiro gráfico
    ax3 = plt.subplot(3, 1, 3)
    sns.lineplot(data=df, x='mes', y='Aceleracao', ax=ax3)
    ax3.set_title("Aceleração")

    plt.tight_layout()
    plt.show()


plotagem_graficos_tres()
